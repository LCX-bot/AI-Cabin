# %%
print("Hello, Jupyter! I am from Runoob!！")
# Out:
# Hello, Jupyter! I am from Runoob!！

# %%
# 这是一个代码单元格
print("Hello, Jupyter!")
print("1 + 2 =", 1 + 2)

# 尝试运行这个单元格（Shift+Enter），看看结果吧！
# Out:
# Hello, Jupyter!
# 1 + 2 = 3

# %%
111
